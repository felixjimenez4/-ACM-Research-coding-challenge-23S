# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd 
df = pd.read_csv("6 class csv.csv")
df
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
df.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
stars = pd.DataFrame()
for key in df[['Temperature (K)','Luminosity(L/Lo)','Radius(R/Ro)','Absolute magnitude(Mv)']]:
    stars[key] = df.groupby('Star type')[key].mean().tolist()

stars
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)
# 0         2997.950          0.000693      0.110015               17.563500
# 1         3283.825          0.005406      0.348145               12.539975
# 2        13931.450          0.002434      0.010728               12.582500
# 3        16018.000      32067.386275      4.430300               -0.367425
# 4        15347.850     301816.250000     51.150000               -6.369925
# 5        11405.700     309246.525000   1366.897500               -9.654250

# %%
stars['Temperature (K)'].plot(kind ='bar',colormap ='coolwarm')
# Out:
# <AxesSubplot: >

# %%
stars['Luminosity(L/Lo)'].plot(kind ='bar',logy = True)
# Out:
# <AxesSubplot: >

# %%
stars['Radius(R/Ro)'].plot(kind ='bar', logy = True)
# Out:
# <AxesSubplot: >

# %%
stars['Absolute magnitude(Mv)'].plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
df['Star color'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot: ylabel='Star color'>

# %% [markdown]
# # The most average star with

# %%
avg_star = pd.DataFrame();
for key in df[['Temperature (K)','Luminosity(L/Lo)','Radius(R/Ro)','Absolute magnitude(Mv)']]:
    avg_star[key] = df[key].mean()
avg_star
# Out:
# Empty DataFrame
# Columns: [Temperature (K), Luminosity(L/Lo), Radius(R/Ro), Absolute magnitude(Mv)]
# Index: []

# %%
avg_star_color = df.groupby(['Star color']).mean()
avg_star_color
# Out:
# C:\Users\rando\AppData\Local\Temp\ipykernel_3132\255779816.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_star_color = df.groupby(['Star color']).mean()
#                     Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# Star color
# Blue                   21955.763636     254519.727561    218.707713
# Blue                   19860.000000          0.001100      0.013100
# Blue White             14638.900000          0.007491      0.010459
# Blue white             10135.333333          0.000600      0.009313
# Blue white             11900.000000          0.000670      0.008980
# Blue-White              8945.000000         38.000000      2.487000
# Blue-white             18669.923077     108655.500000    292.892538
# ...

# %% [markdown]
# # The Temperature of the average star by color

# %%
avg_star_color["Temperature (K)"].sort_values().plot( kind = ("bar"))
# Out:
# <AxesSubplot: xlabel='Star color'>

# %% [markdown]
# # The Luminosity of the average star  by colors

# %%
avg_star_color["Luminosity(L/Lo)"].sort_values().plot( kind = ("bar"), logy = True)
# Out:
# <AxesSubplot: xlabel='Star color'>

# %%
avg_star_color["Radius(R/Ro)"].sort_values().plot( kind = ("bar"), logy = True)
# Out:
# <AxesSubplot: xlabel='Star color'>

# %%
avg_star_color["Absolute magnitude(Mv)"].sort_values().plot( kind = ("bar"))
# Out:
# <AxesSubplot: xlabel='Star color'>

# %%
sns.df[['Temperature (K)','Absolute magnitude(Mv)']]
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(data = df, x = "Temperature (K)", y = "Absolute magnitude(Mv)")
plt.gca().set_ylim(plt.gca().get_ylim()[::-1])
plt.gca().set_xlim(plt.gca().get_xlim()[::-1])
plt.show()

# %%
# Out:
# (1.0, 0.0)
